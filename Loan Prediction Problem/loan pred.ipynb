# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('./train_u6lujuX_CVtuZ9i.csv')

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.notnull()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0       True    True     True        True       True           True
# 1       True    True     True        True       True           True
# 2       True    True     True        True       True           True
# 3       True    True     True        True       True           True
# 4       True    True     True        True       True           True
# ..       ...     ...      ...         ...        ...            ...
# 609     True    True     True        True       True           True
# 610     True    True     True        True       True           True
# 611     True    True     True        True       True           True
# 612     True    True     True        True       True           True
# 613     True    True     True        True       True           True
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               True               True       False              True
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
df= df[["Dependents", "Education", 'Self_Employed', 'ApplicantIncome', 'LoanAmount', 'Loan_Status' ]]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Dependents       599 non-null    object
#  1   Education        614 non-null    object
#  2   Self_Employed    582 non-null    object
#  3   ApplicantIncome  614 non-null    int64
#  4   LoanAmount       592 non-null    float64
#  5   Loan_Status      614 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 28.9+ KB

# %%
df.dropna(inplace=True)
# Out:
# C:\Users\sayan\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
df.head()
# Out:
#   Dependents     Education Self_Employed  ApplicantIncome  LoanAmount  \
# 1          1      Graduate            No             4583       128.0
# 2          0      Graduate           Yes             3000        66.0
# 3          0  Not Graduate            No             2583       120.0
# 4          0      Graduate            No             6000       141.0
# 5          2      Graduate           Yes             5417       267.0
#
#   Loan_Status
# 1           N
# 2           Y
# 3           Y
# 4           Y
# 5           Y

# %%
df.shape
# Out:
# (548, 6)

# %%
new_values = pd.get_dummies(df[['Education', 'Self_Employed', 'Loan_Status']], drop_first=True)

# %%
df= pd.concat([df[['Dependents', 'ApplicantIncome', 'LoanAmount']],new_values],axis=1)

# %%
df.head()
# Out:
#   Dependents  ApplicantIncome  LoanAmount  Education_Not Graduate  \
# 1          1             4583       128.0                       0
# 2          0             3000        66.0                       0
# 3          0             2583       120.0                       1
# 4          0             6000       141.0                       0
# 5          2             5417       267.0                       0
#
#    Self_Employed_Yes  Loan_Status_Y
# 1                  0              0
# 2                  1              1
# 3                  0              1
# 4                  0              1
# 5                  1              1

# %%
df['Dependents'] = df['Dependents'].replace(to_replace='3+',value='4').astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 548 entries, 1 to 613
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Dependents              548 non-null    int32
#  1   ApplicantIncome         548 non-null    int64
#  2   LoanAmount              548 non-null    float64
#  3   Education_Not Graduate  548 non-null    uint8
#  4   Self_Employed_Yes       548 non-null    uint8
#  5   Loan_Status_Y           548 non-null    uint8
# dtypes: float64(1), int32(1), int64(1), uint8(3)
# memory usage: 16.6 KB

# %%
x= df.drop(['Loan_Status_Y'] ,axis=1)
y=df['Loan_Status_Y']

# %%
x = np.array(x)
y = np.array(y)

# %% [markdown]
# ## logisticregression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
model= lr.fit(x,y)
model.score(x,y)
# Out:
# 0.6952554744525548

# %% [markdown]
# ## randomforest

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()
model = clf.fit(x,y)
model.score(x,y)
# Out:
# 1.0

# %% [markdown]
# ## naive bayes

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
model = nb.fit(x,y)
model.score(x,y)
# Out:
# 0.6843065693430657

# %% [markdown]
# ## svm

# %%
from sklearn import svm
clf = svm.SVC()
model = clf.fit(x,y)
model.score(x,y)
# Out:
# 0.6970802919708029

# %% [markdown]
# ## decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
model = clf.fit(x,y)
model.score(x,y)
# Out:
# 1.0

# %% [markdown]
# ## random forest classification

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()
model = clf.fit(x,y)
model.score(x,y)
# Out:
# 1.0
